# %% [markdown]
# # 数据清洗和缺失值处理

# %%
# !pip install chardet

# %% [markdown]
# ## 确定编码方式：ISO-8859-1

# %%
import chardet

def detect_encoding(file_path):
    with open(file_path, 'rb') as file:
        raw_data = file.read()
        result = chardet.detect(raw_data)
        print(f"Detected encoding for {file_path} is {result['encoding']} with confidence {result['confidence']}")

# 示例使用
detect_encoding('GlobalYouTubeStatistics.csv')
# Out:
# Detected encoding for GlobalYouTubeStatistics.csv is ISO-8859-1 with confidence 0.7289153199558486

# %%
import pandas as pd

# 加载数据集
data = pd.read_csv('GlobalYouTubeStatistics.csv',encoding = "ISO-8859-1")
# 查看数据的基本信息
print(data.info())
print(data.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 995 entries, 0 to 994
# Data columns (total 28 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   rank                                     995 non-null    int64
#  1   Youtuber                                 995 non-null    object
#  2   subscribers                              995 non-null    int64
#  3   video views                              995 non-null    float64
#  4   category                                 949 non-null    object
#  5   Title                                    995 non-null    object
#  6   uploads                                  995 non-null    int64
#  7   Country                                  873 non-null    object
#  8   Abbreviation                             873 non-null    object
#  9   channel_type                             965 non-null    object
# ...

# %%
data.columns
# Out:
# Index(['rank', 'Youtuber', 'subscribers', 'video views', 'category', 'Title',
#        'uploads', 'Country', 'Abbreviation', 'channel_type',
#        'video_views_rank', 'country_rank', 'channel_type_rank',
#        'video_views_for_the_last_30_days', 'lowest_monthly_earnings',
#        'highest_monthly_earnings', 'lowest_yearly_earnings',
#        'highest_yearly_earnings', 'subscribers_for_last_30_days',
#        'created_year', 'created_month', 'created_date',
#        'Gross tertiary education enrollment (%)', 'Population',
#        'Unemployment rate', 'Urban_population', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
data.head(20)
# Out:
#     rank                    Youtuber  subscribers   video views  \
# 0      1                    T-Series    245000000  2.280000e+11
# 1      2              YouTube Movies    170000000  0.000000e+00
# 2      3                     MrBeast    166000000  2.836884e+10
# 3      4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4      5                   SET India    159000000  1.480000e+11
# 5      6                       Music    119000000  0.000000e+00
# 6      7         ýýý Kids Diana Show    112000000  9.324704e+10
# 7      8                   PewDiePie    111000000  2.905804e+10
# 8      9                 Like Nastya    106000000  9.047906e+10
# 9     10               Vlad and Niki     98900000  7.718017e+10
# 10    11           Zee Music Company     96700000  5.785629e+10
# 11    12                         WWE     96000000  7.742847e+10
# 12    13                      Gaming     93600000  0.000000e+00
# 13    14                   BLACKPINK     89800000  3.214460e+10
# ...

# %%
for column in data.select_dtypes(include=[object]).columns:
    # 用众数填充
    data[column].fillna(data[column].mode()[0], inplace=True)

# 填充数值型特征的缺失值
for column in data.select_dtypes(include=[np.number]).columns:
    # 用中位数填充
    data[column].fillna(data[column].median(), inplace=True)

# %%
import pandas as pd

# Sample data (replace with your actual DataFrame)
data = pd.DataFrame({
    'created_month': ['Mar', 'Feb', 'Sep', 'Sep', 'Jan', 'Feb', 'Sep', 'Sep', 'May', 'Aug'],
    'created_date': [13.0, 20.0, 1.0, 20.0, 14.0, 12.0, 14.0, 11.0, 9.0, 1.0],
    'created_year': [2006.0, 2012.0, 2006.0, 2006.0, 2016.0, 2017.0, 2018.0, 2006.0, 2012.0, 2017.0]
})


#Ensure created_date is an integer
data['created_date'] = data['created_date'].astype(int)

# Create a properly formatted date string
data['date_string'] = data.apply(lambda row: f"{int(row['created_year'])}-{row['created_month']}-{row['created_date']}", axis=1)

# Convert to datetime, handling errors
data['created_date'] = pd.to_datetime(data['date_string'], format='%Y-%b-%d', errors='coerce')

# Calculate the time difference
target_date = pd.to_datetime('2023-09-15')
data['duration'] = (target_date - data['created_date']).dt.days

print(data)
# Out:
#   created_month created_date  created_year  date_string  duration
# 0           Mar   2006-03-13        2006.0  2006-Mar-13      6395
# 1           Feb   2012-02-20        2012.0  2012-Feb-20      4225
# 2           Sep   2006-09-01        2006.0   2006-Sep-1      6223
# 3           Sep   2006-09-20        2006.0  2006-Sep-20      6204
# 4           Jan   2016-01-14        2016.0  2016-Jan-14      2801
# 5           Feb   2017-02-12        2017.0  2017-Feb-12      2406
# 6           Sep   2018-09-14        2018.0  2018-Sep-14      1827
# 7           Sep   2006-09-11        2006.0  2006-Sep-11      6213
# 8           May   2012-05-09        2012.0   2012-May-9      4146
# 9           Aug   2017-08-01        2017.0   2017-Aug-1      2236

# %%
data['date_string']
# Out:
# 0    2006-Mar-13
# 1    2012-Feb-20
# 2     2006-Sep-1
# 3    2006-Sep-20
# 4    2016-Jan-14
# 5    2017-Feb-12
# 6    2018-Sep-14
# 7    2006-Sep-11
# 8     2012-May-9
# 9     2017-Aug-1
# Name: date_string, dtype: object
